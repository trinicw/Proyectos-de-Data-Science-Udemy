# %% [markdown]
# # Proyecto del Día 5: Generador de Tablas de Multiplicar

# %% [markdown]
# Este proyecto de Python permite al usuario generar tablas de multiplicar para cualquier número y hasta un límite específico de multiplicación.
#
# ## Consigna
# Vas a crear un código que le pida al usuario un **número para multiplicar**, y un **número límite** para establecer hasta cuánto lo vamos a multiplicar.
#
# Por ejemplo, si el usuario elige:
# - Número: 5
# - Límite: 3
#
# El programa le devolverá:
# ```
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# ````
#
# Cuando el programa termine de mostrar los resultados, debe preguntarle al usuario si desea calcular otra tabla, o finalizar el programa.
#
# **Recomendaciones**:
# - Crear una función que se encargue de calcular las tablas
# - Crear una función global que se encargue de:
#     - Solicitar al usuario un número para generar su tabla de multiplicar.
#     - Pedir el límite hasta donde se quiere llegar en la multiplicación.
#     - Llamar a la función que crea las tablas
#
# - Emplear bucles `for` y la función `range` para la lógica de la tabla.
# - Implementar un bucle `while` para que el usuario pueda generar múltiples tablas o salir del programa.

# %%
def calcular_tablas(numero_multiplicando,limite):
    for multiplicador in range(1, limite+1):
        resultado_multiplicacion = numero_multiplicando*multiplicador
        print(f"{numero_multiplicando} x {multiplicador} = {resultado_multiplicacion}")
    return resultado_multiplicacion

# %%
while True:
    print("\nMenú de Opciones:")
    print("1. Calcular tablas")
    print("2. Salir del programa")

    opcion = input("Elija una opción (1 o 2): ")

    if opcion == "1":
        # Validar número a multiplicar
        while True:
            numero_input = input("Ingresa un número para generar su tabla de multiplicar: ")
            if numero_input.lstrip('-').isdigit():
                numero = int(numero_input)
                break
            else:
                print("⚠️ Por favor, ingresá un número válido (entero).")

        # Validar límite
        while True:
            limite_input = input("Hasta dónde querés llegar con la multiplicación: ")
            if limite_input.isdigit():
                limite = int(limite_input)
                if limite > 0:
                    break
                else:
                    print("⚠️ El límite debe ser mayor a 0.")
            else:
                print("⚠️ Por favor, ingresá un número entero positivo.")

        # Calcular tabla
        calcular_tablas(numero, limite)

    elif opcion == "2":
        print("👋 ¡Adiós!")
        break

    else:
        print("⚠️ Opción inválida. Por favor elegí 1 o 2.")
# Out:
# Menú de Opciones:
# 1. Calcular tablas
# 2. Salir del programa
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
#
# Menú de Opciones:
# 1. Calcular tablas
# 2. Salir del programa
# 100 x 1 = 100
# 100 x 2 = 200
# 100 x 3 = 300
# 100 x 4 = 400
# 100 x 5 = 500
# 100 x 6 = 600
# 100 x 7 = 700
# 100 x 8 = 800
# 100 x 9 = 900
# 100 x 10 = 1000
# 100 x 11 = 1100
# 100 x 12 = 1200
# 100 x 13 = 1300
# 100 x 14 = 1400
# 100 x 15 = 1500
# 100 x 16 = 1600
# 100 x 17 = 1700
# 100 x 18 = 1800
# 100 x 19 = 1900
# 100 x 20 = 2000
# 100 x 21 = 2100
# 100 x 22 = 2200
# 100 x 23 = 2300
# 100 x 24 = 2400
# 100 x 25 = 2500
# 100 x 26 = 2600
# 100 x 27 = 2700
# 100 x 28 = 2800
# 100 x 29 = 2900
# 100 x 30 = 3000
# 100 x 31 = 3100
# 100 x 32 = 3200
# 100 x 33 = 3300
# 100 x 34 = 3400
# 100 x 35 = 3500
# 100 x 36 = 3600
# 100 x 37 = 3700
# 100 x 38 = 3800
# 100 x 39 = 3900
# 100 x 40 = 4000
# 100 x 41 = 4100
# 100 x 42 = 4200
# 100 x 43 = 4300
# 100 x 44 = 4400
# 100 x 45 = 4500
# 100 x 46 = 4600
# 100 x 47 = 4700
# 100 x 48 = 4800
# 100 x 49 = 4900
# 100 x 50 = 5000
# 100 x 51 = 5100
# 100 x 52 = 5200
# 100 x 53 = 5300
# 100 x 54 = 5400
# 100 x 55 = 5500
# 100 x 56 = 5600
# 100 x 57 = 5700
# 100 x 58 = 5800
# 100 x 59 = 5900
# 100 x 60 = 6000
# 100 x 61 = 6100
# 100 x 62 = 6200
# 100 x 63 = 6300
# 100 x 64 = 6400
# 100 x 65 = 6500
# 100 x 66 = 6600
# 100 x 67 = 6700
# 100 x 68 = 6800
# 100 x 69 = 6900
# 100 x 70 = 7000
# 100 x 71 = 7100
# 100 x 72 = 7200
# 100 x 73 = 7300
# 100 x 74 = 7400
# 100 x 75 = 7500
# 100 x 76 = 7600
# 100 x 77 = 7700
# 100 x 78 = 7800
# 100 x 79 = 7900
# 100 x 80 = 8000
# 100 x 81 = 8100
# 100 x 82 = 8200
# 100 x 83 = 8300
# 100 x 84 = 8400
# 100 x 85 = 8500
# 100 x 86 = 8600
# 100 x 87 = 8700
# 100 x 88 = 8800
# 100 x 89 = 8900
# 100 x 90 = 9000
# 100 x 91 = 9100
# 100 x 92 = 9200
# 100 x 93 = 9300
# 100 x 94 = 9400
# 100 x 95 = 9500
# 100 x 96 = 9600
# 100 x 97 = 9700
# 100 x 98 = 9800
# 100 x 99 = 9900
# 100 x 100 = 10000
# 100 x 101 = 10100
# 100 x 102 = 10200
# 100 x 103 = 10300
# 100 x 104 = 10400
# 100 x 105 = 10500
# 100 x 106 = 10600
# 100 x 107 = 10700
# 100 x 108 = 10800
# 100 x 109 = 10900
# 100 x 110 = 11000
# 100 x 111 = 11100
# 100 x 112 = 11200
# 100 x 113 = 11300
# 100 x 114 = 11400
# 100 x 115 = 11500
# 100 x 116 = 11600
# 100 x 117 = 11700
# 100 x 118 = 11800
# 100 x 119 = 11900
# 100 x 120 = 12000
# 100 x 121 = 12100
# 100 x 122 = 12200
# 100 x 123 = 12300
# 100 x 124 = 12400
# 100 x 125 = 12500
# 100 x 126 = 12600
# 100 x 127 = 12700
# 100 x 128 = 12800
# 100 x 129 = 12900
# 100 x 130 = 13000
# 100 x 131 = 13100
# 100 x 132 = 13200
# 100 x 133 = 13300
# 100 x 134 = 13400
# 100 x 135 = 13500
# 100 x 136 = 13600
# 100 x 137 = 13700
# 100 x 138 = 13800
# 100 x 139 = 13900
# 100 x 140 = 14000
# 100 x 141 = 14100
# 100 x 142 = 14200
# 100 x 143 = 14300
# 100 x 144 = 14400
# 100 x 145 = 14500
# 100 x 146 = 14600
# 100 x 147 = 14700
# 100 x 148 = 14800
# 100 x 149 = 14900
# 100 x 150 = 15000
# 100 x 151 = 15100
# 100 x 152 = 15200
# 100 x 153 = 15300
# 100 x 154 = 15400
# 100 x 155 = 15500
# 100 x 156 = 15600
# 100 x 157 = 15700
# 100 x 158 = 15800
# 100 x 159 = 15900
# 100 x 160 = 16000
# 100 x 161 = 16100
# 100 x 162 = 16200
# 100 x 163 = 16300
# 100 x 164 = 16400
# 100 x 165 = 16500
# 100 x 166 = 16600
# 100 x 167 = 16700
# 100 x 168 = 16800
# 100 x 169 = 16900
# 100 x 170 = 17000
# 100 x 171 = 17100
# 100 x 172 = 17200
# 100 x 173 = 17300
# 100 x 174 = 17400
# 100 x 175 = 17500
# 100 x 176 = 17600
# 100 x 177 = 17700
# 100 x 178 = 17800
# 100 x 179 = 17900
# 100 x 180 = 18000
# 100 x 181 = 18100
# 100 x 182 = 18200
# 100 x 183 = 18300
# 100 x 184 = 18400
# 100 x 185 = 18500
# 100 x 186 = 18600
# 100 x 187 = 18700
# 100 x 188 = 18800
# 100 x 189 = 18900
# 100 x 190 = 19000
# 100 x 191 = 19100
# 100 x 192 = 19200
# 100 x 193 = 19300
# 100 x 194 = 19400
# 100 x 195 = 19500
# 100 x 196 = 19600
# 100 x 197 = 19700
# 100 x 198 = 19800
# 100 x 199 = 19900
# 100 x 200 = 20000
# 100 x 201 = 20100
# 100 x 202 = 20200
# 100 x 203 = 20300
# 100 x 204 = 20400
# 100 x 205 = 20500
# 100 x 206 = 20600
# 100 x 207 = 20700
# 100 x 208 = 20800
# 100 x 209 = 20900
# 100 x 210 = 21000
# 100 x 211 = 21100
# 100 x 212 = 21200
# 100 x 213 = 21300
# 100 x 214 = 21400
# 100 x 215 = 21500
# 100 x 216 = 21600
# 100 x 217 = 21700
# 100 x 218 = 21800
# 100 x 219 = 21900
# 100 x 220 = 22000
# 100 x 221 = 22100
# 100 x 222 = 22200
# 100 x 223 = 22300
# 100 x 224 = 22400
# 100 x 225 = 22500
# 100 x 226 = 22600
# 100 x 227 = 22700
# 100 x 228 = 22800
# 100 x 229 = 22900
# 100 x 230 = 23000
# 100 x 231 = 23100
# 100 x 232 = 23200
# 100 x 233 = 23300
# 100 x 234 = 23400
# 100 x 235 = 23500
# 100 x 236 = 23600
# 100 x 237 = 23700
# 100 x 238 = 23800
# 100 x 239 = 23900
# 100 x 240 = 24000
# 100 x 241 = 24100
# 100 x 242 = 24200
# 100 x 243 = 24300
# 100 x 244 = 24400
# 100 x 245 = 24500
# 100 x 246 = 24600
# 100 x 247 = 24700
# 100 x 248 = 24800
# 100 x 249 = 24900
# 100 x 250 = 25000
#
# Menú de Opciones:
# 1. Calcular tablas
# 2. Salir del programa
# 👋 ¡Adiós!

# %% [markdown]
# # Proyecto del Día 4: Agenda de Contactos Interactiva
#
# ### Objetivo
# Crear una agenda de contactos utilizando Python, aplicando los conceptos aprendidos sobre listas, tuplas, diccionarios, booleanos y estructuras de control.
#
#
# ### Consigna
# Cada vez que inicies tu agenda, va a comenzar preguntándole al usuario cuál de estas opciones prefiere:
# 1. **Añadir un contacto**: Crear un nuevo registro en la agenda (nombre, telefono).
# 2. **Buscar un contacto**: Buscar un contacto por nombre y mostrar su teléfono, o un mensaje de error si no lo encuentra.
# 3. **Editar un contacto**: Modificar teléfono de un contacto existente.
# 4. **Eliminar un contacto**: Eliminar un contacto de la agenda (investiga los métodos disponibles para lograrlo)
# 5. **Mostrar todos los contactos**: Mostrar todos los contactos guardados en la agenda.
#
# El usuario elegirá una de esas opciones, y el programa ejecutará el código correspondiente para procesar su pedido y mostrarle el resultado.
#
#
# ### Notas y Ayudas
# - Debido a que vas a almacenar pares de datos (nombre y teléfono) ¿cuál crees que sería la mejor estructura de datos para guardarlos: **listas**, **tuplas** o **diccionarios**?
# - Algunas de las funcionalidades de tu agenda, pueden requerir que investigues algunos métodos que no hemos visto en las lecciones, pero que podrás descubrir con *type*, *dir* y *help*.
# <br>
# <br>
# <br>

# %%
agenda = {}

while True:
    print("\nElije una opcion:")
    print("1. Agregar un contacto")
    print("2. Buscar un contacto")
    print("3. Editar un contacto")
    print("4. Eliminar un contacto")
    print("5. Mostrar todos los contactos")
    print("6. Salir")

    opcion = input("Elige una opcion: ")

    if opcion == '1':    
        nombre = input("Nombre del contacto: ")
        telefono = input("Telefono del contacto: ")
        agenda[nombre] = telefono
        print(f"Contacto {nombre} agregado con telefono {telefono}.")   

    elif opcion == '2':
        nombre_a_buscar = input("Nombre del contacto a buscar: ")
        if nombre_a_buscar in agenda:
            print(f"El telefono del contacto {nombre_a_buscar} es : {agenda[nombre_a_buscar]}")
        else:
            print(f"El contacto {nombre_a_buscar} no existe en la agenda.")

    elif opcion == '3':
        nombre_a_buscar = input("Nombre del contacto a buscar: ")
        if nombre_a_buscar in agenda:
            print(f"Contacto : {nombre_a_buscar} | Telefono actual : {agenda[nombre_a_buscar]}")
            telefono_modificado = input("Ingresa el nuevo numero de telefono: ")
            agenda[nombre_a_buscar] = telefono_modificado
            print(f"Contacto : {nombre_a_buscar} | Nuevo telefono : {agenda[nombre_a_buscar]}")
        else:
            print(f"El contacto {nombre_a_buscar} no existe en la agenda.")

    elif opcion == '4':
        nombre_a_eliminar = input("Ingresa el nombre del contacto a eliminar")
        if nombre_a_eliminar in agenda:
            del agenda[nombre_a_eliminar]
            print(f"el contacto {nombre_a_eliminar} ha sido eliminado")
        else:
            print(f"El contacto {nombre_a_eliminar} no está en la agenda")

    elif opcion == '5':
        print(" | Contactos de la agenda | ")
        print(agenda)

    elif opcion == '6':
        print("Saliendo del programa... ¡Hasta luego!")
        break

    else:
        print("Opcion no valida")
# Out:
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
#  | Contactos de la agenda |
# {}
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Contacto trinidad agregado con telefono 234.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Contacto renzo agregado con telefono 223578.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Contacto bibiana agregado con telefono 789999.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Contacto damian agregado con telefono 48583822.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# El telefono del contacto renzo es : 223578
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# El telefono del contacto damian es : 48583822
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Contacto : renzo | Telefono actual : 223578
# Contacto : renzo | Nuevo telefono : 111111111
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# El telefono del contacto renzo es : 111111111
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# el contacto renzo ha sido eliminado
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# El contacto renzo no existe en la agenda.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# El contacto renzo no existe en la agenda.
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
#  | Contactos de la agenda |
# {'trinidad': '234', 'bibiana': '789999', 'damian': '48583822'}
#
# Elije una opcion:
# 1. Agregar un contacto
# 2. Buscar un contacto
# 3. Editar un contacto
# 4. Eliminar un contacto
# 5. Mostrar todos los contactos
# 6. Salir
# Saliendo del programa... ¡Hasta luego!
